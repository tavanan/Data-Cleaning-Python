# %% [markdown]
# # Data Cleaning with Python
#
#
# ---
# **author**:
#   - **Nader Tavana**
#
# ---

# %% [markdown]
# ### Introduction:
# The aim of this project is to analyse the data sets to understand different features of variables.Firstly we will look that how to read the data.The data are in XML format therefore we need to parse it and then convert it to pandas dataframe.Then we look at basic statistics and getting the columns that exist in every data set, also we see how to deal with missing values and replace them with NA and some other features which will be explained step by step.
#
# The data sets that i used for this project are three different websites included:
# - **travel.stackexchange.com.7z** ,  size:115 MB
# - **astronomy.stackexchange.com.7z**  , size:30 MB
# - **health.stackexchange.com.7z** ,  size:17 MB

# %% [markdown]
# We use **xml.etree.cElementTree** to parse xml

# %%
import xml.etree.cElementTree as et
import pandas as pd
import numpy as np

# %% [markdown]
# Here is the definition of the **Parsing** function which takes the path of data set as argument and from the root it iterates over every tag name 'row' and extract the data then appened it to the list and then we convert that list to a dataframe.

# %%
def parsing(path):

    data = et.iterparse(path, events=("start", "end"))
    data = iter(data)
    lis=[]
    ev, root = next(data)
    for ev, el in data:
        if ev == 'start' and el.tag == 'row':
            lis.append(el.attrib)

            root.clear()

    return pd.DataFrame(lis)

# %% [markdown]
# After defining the parsing function,below we define a fucntion to read the data from a given path which use parsing function inside for every table in a data set then return all the tables.to not get confused with the table names i used website name as the begining of the every table.

# %%
# function for reading dataset
def readData(path):
       Posts=parsing(path+"Posts.xml")
       Comments=parsing(path+"Comments.xml")
       Badges=parsing(path+"Badges.xml")
       PostLinks=parsing(path+"PostLinks.xml")
       PostHistory=parsing(path+"PostHistory.xml")
       Tags=parsing(path+"Tags.xml")
       Users=parsing(path+"Users.xml")
       Votes=parsing(path+"Votes.xml")
       return (Posts,Comments,Badges,PostLinks,PostHistory,Tags,Users,Votes)


# reading travel dataset
path='D:Project2/travel/'
travel_Posts,travel_Comments,travel_Badges,travel_PostLinks,travel_PostHistory,travel_Tags,travel_Users,travel_Votes=readData(path)

#reading health dataset
path='D:Project2/health/'
health_Posts,health_Comments,health_Badges,health_PostLinks,health_PostHistory,health_Tags,health_Users,health_Votes=readData(path)

#reading astronomy dataset
path='D:Project2/astronomy/'
astro_Posts,astro_Comments,astro_Badges,astro_PostLinks,astro_PostHistory,astro_Tags,astro_Users,astro_Votes=readData(path)

# %% [markdown]
# \
# \
# Next we see that which variables are in table.As we know that all datasets have same tables so i just prin tfor travel dataset to see the name of variables.

# %%
print('Posts: ',list(travel_Posts.columns),'\n')
print('Comment: ',list(travel_Comments.columns),'\n')
print('Badges: ',list(travel_Badges.columns),'\n')
print('PostHistory: ',list(travel_PostHistory.columns),'\n')
print('PostLinks: ',list(travel_PostLinks.columns),'\n')
print('Tags: ',list(travel_Tags.columns),'\n')
print('Users: ',list(travel_Users.columns),'\n')
print('Votes: ',list(travel_Votes.columns),'\n')
# Out:
# Posts:  ['Id', 'PostTypeId', 'AcceptedAnswerId', 'CreationDate', 'Score', 'ViewCount', 'Body', 'OwnerUserId', 'LastEditorUserId', 'LastEditDate', 'LastActivityDate', 'Title', 'Tags', 'AnswerCount', 'CommentCount', 'ClosedDate', 'ContentLicense', 'FavoriteCount', 'ParentId', 'LastEditorDisplayName', 'CommunityOwnedDate', 'OwnerDisplayName']
#
# Comment:  ['Id', 'PostId', 'Score', 'Text', 'CreationDate', 'UserId', 'ContentLicense', 'UserDisplayName']
#
# Badges:  ['Id', 'UserId', 'Name', 'Date', 'Class', 'TagBased']
#
# PostHistory:  ['Id', 'PostHistoryTypeId', 'PostId', 'RevisionGUID', 'CreationDate', 'UserId', 'Text', 'ContentLicense', 'Comment', 'UserDisplayName']
#
# PostLinks:  ['Id', 'CreationDate', 'PostId', 'RelatedPostId', 'LinkTypeId']
#
# Tags:  ['Id', 'TagName', 'Count', 'ExcerptPostId', 'WikiPostId']
#
# Users:  ['Id', 'Reputation', 'CreationDate', 'DisplayName', 'LastAccessDate', 'WebsiteUrl', 'Location', 'AboutMe', 'Views', 'UpVotes', 'DownVotes', 'AccountId', 'ProfileImageUrl']
#
# Votes:  ['Id', 'PostId', 'VoteTypeId', 'CreationDate', 'UserId', 'BountyAmount']

# %% [markdown]
# \
# \
# Creating every dataset as a list of its tables so it will be easier to work on single website

# %%
travel=[travel_Posts,travel_Comments,travel_Badges,travel_PostLinks,travel_PostHistory,travel_Tags,travel_Users,travel_Votes]
health=[health_Posts,health_Comments,health_Badges,health_PostLinks,health_PostHistory,health_Tags,health_Users,health_Votes]
astronomy=[astro_Posts,astro_Comments,astro_Badges,astro_PostLinks,astro_PostHistory,astro_Tags,astro_Users,astro_Votes]

# %% [markdown]
# \
# \
# Next we define a function to make a list of missing value in % for each column in the table.Then function takes a website(list of tables for a website and print the percentage of missing value per column).

# %%
# function to information about percentage of missing value
def missing(data):
  for df in data:
     name =[x for x in globals() if globals()[x] is df][0]  # get name of table
     print(name,'\n')
     for col in df.columns:
       pct_missing = np.mean(df[col].isnull()) # get percentage of every column
       print('{} - {}%'.format(col, round(pct_missing*100)))
     print('End of dataframe \n \n')

# %% [markdown]
# #### Printing percentage of missing value per website:

# %% [markdown]
# For travel website:

# %%
missing(travel)
# Out:
# travel_Posts
#
# Id - 0%
# PostTypeId - 0%
# AcceptedAnswerId - 85%
# CreationDate - 0%
# Score - 0%
# ViewCount - 63%
# Body - 0%
# OwnerUserId - 3%
# LastEditorUserId - 47%
# LastEditDate - 44%
# LastActivityDate - 0%
# Title - 63%
# Tags - 63%
# AnswerCount - 63%
# CommentCount - 0%
# ClosedDate - 92%
# ContentLicense - 0%
# FavoriteCount - 91%
# ParentId - 41%
# LastEditorDisplayName - 96%
# CommunityOwnedDate - 100%
# OwnerDisplayName - 96%
# End of dataframe
#
#
# travel_Comments
#
# Id - 0%
# PostId - 0%
# Score - 0%
# Text - 0%
# CreationDate - 0%
# UserId - 3%
# ContentLicense - 0%
# UserDisplayName - 97%
# End of dataframe
#
#
# travel_Badges
#
# Id - 0%
# UserId - 0%
# Name - 0%
# Date - 0%
# Class - 0%
# TagBased - 0%
# End of dataframe
#
#
# travel_PostLinks
#
# Id - 0%
# CreationDate - 0%
# PostId - 0%
# RelatedPostId - 0%
# LinkTypeId - 0%
# End of dataframe
#
#
# travel_PostHistory
#
# Id - 0%
# PostHistoryTypeId - 0%
# PostId - 0%
# RevisionGUID - 0%
# CreationDate - 0%
# UserId - 12%
# Text - 10%
# ContentLicense - 11%
# Comment - 51%
# UserDisplayName - 96%
# End of dataframe
#
#
# travel_Tags
#
# Id - 0%
# TagName - 0%
# Count - 0%
# ExcerptPostId - 2%
# WikiPostId - 2%
# End of dataframe
#
#
# travel_Users
#
# Id - 0%
# Reputation - 0%
# CreationDate - 0%
# DisplayName - 0%
# LastAccessDate - 0%
# WebsiteUrl - 80%
# Location - 69%
# AboutMe - 72%
# Views - 0%
# UpVotes - 0%
# DownVotes - 0%
# AccountId - 0%
# ProfileImageUrl - 33%
# End of dataframe
#
#
# travel_Votes
#
# Id - 0%
# PostId - 0%
# VoteTypeId - 0%
# CreationDate - 0%
# UserId - 98%
# BountyAmount - 100%
# End of dataframe

# %% [markdown]
# For health website:

# %%
missing(health)
# Out:
# health_Posts
#
# Id - 0%
# PostTypeId - 0%
# AcceptedAnswerId - 83%
# CreationDate - 0%
# Score - 0%
# ViewCount - 48%
# Body - 0%
# OwnerUserId - 2%
# LastEditorUserId - 44%
# LastEditDate - 43%
# LastActivityDate - 0%
# Title - 48%
# Tags - 48%
# AnswerCount - 48%
# CommentCount - 0%
# FavoriteCount - 86%
# ContentLicense - 0%
# ParentId - 56%
# LastEditorDisplayName - 99%
# OwnerDisplayName - 97%
# ClosedDate - 94%
# CommunityOwnedDate - 100%
# End of dataframe
#
#
# health_Comments
#
# Id - 0%
# PostId - 0%
# Score - 0%
# Text - 0%
# CreationDate - 0%
# UserId - 2%
# ContentLicense - 0%
# UserDisplayName - 98%
# End of dataframe
#
#
# health_Badges
#
# Id - 0%
# UserId - 0%
# Name - 0%
# Date - 0%
# Class - 0%
# TagBased - 0%
# End of dataframe
#
#
# health_PostLinks
#
# Id - 0%
# CreationDate - 0%
# PostId - 0%
# RelatedPostId - 0%
# LinkTypeId - 0%
# End of dataframe
#
#
# health_PostHistory
#
# Id - 0%
# PostHistoryTypeId - 0%
# PostId - 0%
# RevisionGUID - 0%
# CreationDate - 0%
# UserId - 6%
# Text - 8%
# ContentLicense - 7%
# Comment - 59%
# UserDisplayName - 97%
# End of dataframe
#
#
# health_Tags
#
# Id - 0%
# TagName - 0%
# Count - 0%
# ExcerptPostId - 87%
# WikiPostId - 87%
# End of dataframe
#
#
# health_Users
#
# Id - 0%
# Reputation - 0%
# CreationDate - 0%
# DisplayName - 0%
# LastAccessDate - 0%
# Location - 60%
# AboutMe - 63%
# Views - 0%
# UpVotes - 0%
# DownVotes - 0%
# AccountId - 0%
# ProfileImageUrl - 14%
# WebsiteUrl - 78%
# End of dataframe
#
#
# health_Votes
#
# Id - 0%
# PostId - 0%
# VoteTypeId - 0%
# CreationDate - 0%
# UserId - 96%
# BountyAmount - 100%
# End of dataframe

# %% [markdown]
# \
# \
# For astronomy website

# %%
missing(astronomy)
# Out:
# astro_Posts
#
# Id - 0%
# PostTypeId - 0%
# AcceptedAnswerId - 79%
# CreationDate - 0%
# Score - 0%
# ViewCount - 60%
# Body - 0%
# OwnerUserId - 2%
# LastEditorUserId - 54%
# LastEditDate - 53%
# LastActivityDate - 0%
# Title - 60%
# Tags - 60%
# AnswerCount - 60%
# CommentCount - 0%
# FavoriteCount - 89%
# ContentLicense - 0%
# OwnerDisplayName - 97%
# ParentId - 43%
# LastEditorDisplayName - 99%
# ClosedDate - 96%
# CommunityOwnedDate - 100%
# End of dataframe
#
#
# astro_Comments
#
# Id - 0%
# PostId - 0%
# Score - 0%
# Text - 0%
# CreationDate - 0%
# UserId - 4%
# ContentLicense - 0%
# UserDisplayName - 96%
# End of dataframe
#
#
# astro_Badges
#
# Id - 0%
# UserId - 0%
# Name - 0%
# Date - 0%
# Class - 0%
# TagBased - 0%
# End of dataframe
#
#
# astro_PostLinks
#
# Id - 0%
# CreationDate - 0%
# PostId - 0%
# RelatedPostId - 0%
# LinkTypeId - 0%
# End of dataframe
#
#
# astro_PostHistory
#
# Id - 0%
# PostHistoryTypeId - 0%
# PostId - 0%
# RevisionGUID - 0%
# CreationDate - 0%
# UserId - 12%
# Text - 12%
# ContentLicense - 11%
# UserDisplayName - 98%
# Comment - 59%
# End of dataframe
#
#
# astro_Tags
#
# Id - 0%
# TagName - 0%
# Count - 0%
# ExcerptPostId - 40%
# WikiPostId - 40%
# End of dataframe
#
#
# astro_Users
#
# Id - 0%
# Reputation - 0%
# CreationDate - 0%
# DisplayName - 0%
# LastAccessDate - 0%
# WebsiteUrl - 78%
# Location - 62%
# AboutMe - 63%
# Views - 0%
# UpVotes - 0%
# DownVotes - 0%
# AccountId - 0%
# ProfileImageUrl - 14%
# End of dataframe
#
#
# astro_Votes
#
# Id - 0%
# PostId - 0%
# VoteTypeId - 0%
# CreationDate - 0%
# UserId - 97%
# BountyAmount - 100%
# End of dataframe

# %% [markdown]
# \
# \
# Now we define a function to replace all missing value with **NA** in a given website as an argument:

# %%
def replaceNA(d):
    for df in d:
        for col in df.columns:
            df[col] = df[col].fillna('NA')



replaceNA(travel)
replaceNA(health)
replaceNA(astronomy)

# printing sample table to see the result
print(travel[0].head())
# Out:
#   Id PostTypeId AcceptedAnswerId             CreationDate Score ViewCount  \
# 0  1          1              393  2011-06-21T20:19:34.730     8       517
# 1  2          1               NA  2011-06-21T20:22:33.760    39      2847
# 2  3          2               NA  2011-06-21T20:24:28.080    15        NA
# 3  4          1               NA  2011-06-21T20:24:57.160     8       288
# 4  5          1              770  2011-06-21T20:25:56.787    14       470
#
#                                                 Body OwnerUserId  \
# 0  <p>My fiancée and I are looking for a good Car...           9
# 1  <p>This was one of our definition questions, b...          13
# 2  <p>One way would be to go through an Adventure...           9
# 3  <p>Singapore Airlines has an all-business clas...          24
# 4  <p>Another definition question that interested...          13
#
#   LastEditorUserId             LastEditDate  ...  \
# 0              101  2011-12-28T21:36:43.910  ...
# 1            50282  2019-11-14T13:06:23.997  ...
# 2               NA                       NA  ...
# 3              693  2013-01-09T09:55:22.743  ...
# 4              101  2011-12-28T21:36:18.230  ...
#
#                                                 Tags AnswerCount CommentCount  \
# 0                   <caribbean><cruising><vacations>           4            4
# 1  <guides><extreme-tourism><amazon-river><amazon...           8            4
# 2                                                 NA          NA            2
# 3  <loyalty-programs><routes><ewr><singapore-airl...           1            1
# 4                          <romania><transportation>           5            0
#
#                 ClosedDate ContentLicense FavoriteCount ParentId  \
# 0  2013-02-25T23:52:47.953   CC BY-SA 3.0            NA       NA
# 1                       NA   CC BY-SA 4.0             5       NA
# 2                       NA   CC BY-SA 3.0            NA        2
# 3                       NA   CC BY-SA 3.0            NA       NA
# 4                       NA   CC BY-SA 3.0             2       NA
#
#   LastEditorDisplayName CommunityOwnedDate OwnerDisplayName
# 0                    NA                 NA               NA
# 1                    NA                 NA               NA
# 2                    NA                 NA               NA
# 3                    NA                 NA               NA
# 4                    NA                 NA               NA
#
# [5 rows x 22 columns]

# %% [markdown]
# \
# \
# Defining function stats which gies some basic statistics of each column and datatype

# %%
def stats(d):
    for df in d:
        name =[x for x in globals() if globals()[x] is df][0]
        print(name,':\n')
        for col in df.columns:
            print(col)
            print(df[col].describe(),'\n\n')

# %% [markdown]
# \
# \
# Statistics of travel website:

# %%
stats(travel)
# Out:
# travel_Posts :
#
# Id
# count     113202
# unique    113202
# top        16206
# freq           1
# Name: Id, dtype: object
#
#
# PostTypeId
# count     113202
# unique         6
# top            2
# freq       66857
# Name: PostTypeId, dtype: object
#
#
# AcceptedAnswerId
# count     113202
# unique     16961
# top           NA
# freq       96242
# Name: AcceptedAnswerId, dtype: object
#
#
# CreationDate
# count                      113202
# unique                     110859
# top       2015-08-17T11:32:26.570
# freq                            2
# Name: CreationDate, dtype: object
#
#
# Score
# count     113202
# unique       199
# top            2
# freq       15032
# Name: Score, dtype: object
#
#
# ViewCount
# count     113202
# unique      8662
# top           NA
# freq       71275
# Name: ViewCount, dtype: object
#
#
# Body
# count     113202
# unique    112741
# top
# freq         424
# Name: Body, dtype: object
#
#
# OwnerUserId
# count     113202
# unique     31783
# top           NA
# freq        3034
# Name: OwnerUserId, dtype: object
#
#
# LastEditorUserId
# count     113202
# unique      5310
# top           NA
# freq       52929
# Name: LastEditorUserId, dtype: object
#
#
# LastEditDate
# count     113202
# unique     57690
# top           NA
# freq       49492
# Name: LastEditDate, dtype: object
#
#
# LastActivityDate
# count                      113202
# unique                      91172
# top       2019-03-07T09:17:27.533
# freq                            2
# Name: LastActivityDate, dtype: object
#
#
# Title
# count     113202
# unique     41922
# top           NA
# freq       71275
# Name: Title, dtype: object
#
#
# Tags
# count     113202
# unique     32218
# top           NA
# freq       71275
# Name: Tags, dtype: object
#
#
# AnswerCount
# count     113202
# unique        27
# top           NA
# freq       71275
# Name: AnswerCount, dtype: object
#
#
# CommentCount
# count     113202
# unique        37
# top            0
# freq       45603
# Name: CommentCount, dtype: object
#
#
# ClosedDate
# count     113202
# unique      9309
# top           NA
# freq      103894
# Name: ClosedDate, dtype: object
#
#
# ContentLicense
# count           113202
# unique               2
# top       CC BY-SA 3.0
# freq             79685
# Name: ContentLicense, dtype: object
#
#
# FavoriteCount
# count     113202
# unique        44
# top           NA
# freq      103319
# Name: FavoriteCount, dtype: object
#
#
# ParentId
# count     113202
# unique     37193
# top           NA
# freq       46345
# Name: ParentId, dtype: object
#
#
# LastEditorDisplayName
# count     113202
# unique       110
# top           NA
# freq      108768
# Name: LastEditorDisplayName, dtype: object
#
#
# CommunityOwnedDate
# count     113202
# unique       295
# top           NA
# freq      112874
# Name: CommunityOwnedDate, dtype: object
#
#
# OwnerDisplayName
# count     113202
# unique       436
# top           NA
# freq      109181
# Name: OwnerDisplayName, dtype: object
#
#
# travel_Comments :
#
# Id
# count     254942
# unique    254942
# top        97501
# freq           1
# Name: Id, dtype: object
#
#
# PostId
# count     254942
# unique     67599
# top        24540
# freq          37
# Name: PostId, dtype: object
#
#
# Score
# count     254942
# unique       123
# top            0
# freq      148342
# Name: Score, dtype: object
#
#
# Text
# count                        254942
# unique                       253838
# top       What is your nationality?
# freq                             62
# Name: Text, dtype: object
#
#
# CreationDate
# count                      254942
# unique                     254939
# top       2011-07-09T01:43:59.837
# freq                            2
# Name: CreationDate, dtype: object
#
#
# UserId
# count     254942
# unique     17664
# top        19400
# freq       10870
# Name: UserId, dtype: object
#
#
# ContentLicense
# count           254942
# unique               2
# top       CC BY-SA 3.0
# freq            174256
# Name: ContentLicense, dtype: object
#
#
# UserDisplayName
# count     254942
# unique       668
# top           NA
# freq      247412
# Name: UserDisplayName, dtype: object
#
#
# travel_Badges :
#
# Id
# count     185539
# unique    185539
# top        16206
# freq           1
# Name: Id, dtype: object
#
#
# UserId
# count     185539
# unique     53985
# top          101
# freq        2135
# Name: UserId, dtype: object
#
#
# Name
# count      185539
# unique        206
# top       Student
# freq        23324
# Name: Name, dtype: object
#
#
# Date
# count                      185539
# unique                     148806
# top       2014-09-24T20:24:02.460
# freq                         2130
# Name: Date, dtype: object
#
#
# Class
# count     185539
# unique         3
# top            3
# freq      149492
# Name: Class, dtype: object
#
#
# TagBased
# count     185539
# unique         2
# top        False
# freq      184569
# Name: TagBased, dtype: object
#
#
# travel_PostLinks :
#
# Id
# count      27404
# unique     27404
# top       510808
# freq           1
# Name: Id, dtype: object
#
#
# CreationDate
# count                       27404
# unique                      25267
# top       2013-02-18T03:03:35.137
# freq                           84
# Name: CreationDate, dtype: object
#
#
# PostId
# count     27404
# unique    15874
# top       92121
# freq         16
# Name: PostId, dtype: object
#
#
# RelatedPostId
# count     27404
# unique     7817
# top       34106
# freq       1097
# Name: RelatedPostId, dtype: object
#
#
# LinkTypeId
# count     27404
# unique        2
# top           1
# freq      19387
# Name: LinkTypeId, dtype: object
#
#
# travel_PostHistory :
#
# Id
# count     402959
# unique    402959
# top        16206
# freq           1
# Name: Id, dtype: object
#
#
# PostHistoryTypeId
# count     402959
# unique        29
# top            2
# freq      113202
# Name: PostHistoryTypeId, dtype: object
#
#
# PostId
# count     402959
# unique    113202
# top       153472
# freq          74
# Name: PostId, dtype: object
#
#
# RevisionGUID
# count                                   402959
# unique                                  280927
# top       3ed42ef9-1abd-4536-9759-56ee08bb3927
# freq                                         5
# Name: RevisionGUID, dtype: object
#
#
# CreationDate
# count                      402959
# unique                     270500
# top       2020-06-16T10:18:57.393
# freq                         2768
# Name: CreationDate, dtype: object
#
#
# UserId
# count     402959
# unique     32277
# top           NA
# freq       49539
# Name: UserId, dtype: object
#
#
# Text
# count     402959
# unique    326421
# top           NA
# freq       42114
# Name: Text, dtype: object
#
#
# ContentLicense
# count           402959
# unique               3
# top       CC BY-SA 3.0
# freq            258069
# Name: ContentLicense, dtype: object
#
#
# Comment
# count     402959
# unique     62993
# top           NA
# freq      204310
# Name: Comment, dtype: object
#
#
# UserDisplayName
# count     402959
# unique       402
# top           NA
# freq      386897
# Name: UserDisplayName, dtype: object
#
#
# travel_Tags :
#
# Id
# count     1890
# unique    1890
# top       2538
# freq         1
# Name: Id, dtype: object
#
#
# TagName
# count           1890
# unique          1890
# top       ecotourism
# freq               1
# Name: TagName, dtype: object
#
#
# Count
# count     1890
# unique     269
# top          1
# freq       199
# Name: Count, dtype: object
#
#
# ExcerptPostId
# count     1890
# unique    1846
# top         NA
# freq        45
# Name: ExcerptPostId, dtype: object
#
#
# WikiPostId
# count     1890
# unique    1846
# top         NA
# freq        45
# Name: WikiPostId, dtype: object
#
#
# travel_Users :
#
# Id
# count     85156
# unique    85156
# top       97501
# freq          1
# Name: Id, dtype: object
#
#
# Reputation
# count     85156
# unique     1514
# top           1
# freq      35648
# Name: Reputation, dtype: object
#
#
# CreationDate
# count                       85156
# unique                      85156
# top       2019-02-21T20:08:06.970
# freq                            1
# Name: CreationDate, dtype: object
#
#
# DisplayName
# count     85156
# unique    74339
# top        John
# freq        124
# Name: DisplayName, dtype: object
#
#
# LastAccessDate
# count                       85156
# unique                      85156
# top       2020-08-01T19:11:25.843
# freq                            1
# Name: LastAccessDate, dtype: object
#
#
# WebsiteUrl
# count     85156
# unique    14741
# top          NA
# freq      68181
# Name: WebsiteUrl, dtype: object
#
#
# Location
# count     85156
# unique     6422
# top          NA
# freq      58488
# Name: Location, dtype: object
#
#
# AboutMe
# count     85156
# unique    21346
# top          NA
# freq      61555
# Name: AboutMe, dtype: object
#
#
# Views
# count     85156
# unique      559
# top           0
# freq      47327
# Name: Views, dtype: object
#
#
# UpVotes
# count     85156
# unique      571
# top           0
# freq      67905
# Name: UpVotes, dtype: object
#
#
# DownVotes
# count     85156
# unique      167
# top           0
# freq      83174
# Name: DownVotes, dtype: object
#
#
# AccountId
# count     85156
# unique    85152
# top          NA
# freq          4
# Name: AccountId, dtype: object
#
#
# ProfileImageUrl
# count     85156
# unique    56584
# top          NA
# freq      27759
# Name: ProfileImageUrl, dtype: object
#
#
# travel_Votes :
#
# Id
# count     924570
# unique    924570
# top       303479
# freq           1
# Name: Id, dtype: object
#
#
# PostId
# count     924570
# unique    133216
# top        98374
# freq         547
# Name: PostId, dtype: object
#
#
# VoteTypeId
# count     924570
# unique        14
# top            2
# freq      758090
# Name: VoteTypeId, dtype: object
#
#
# CreationDate
# count                      924570
# unique                       3457
# top       2016-06-06T00:00:00.000
# freq                         1102
# Name: CreationDate, dtype: object
#
#
# UserId
# count     924570
# unique      4497
# top           NA
# freq      904764
# Name: UserId, dtype: object
#
#
# BountyAmount
# count     924570
# unique        13
# top           NA
# freq      921335
# Name: BountyAmount, dtype: object

# %% [markdown]
# \
# \
# Statistics of health website:

# %%
stats(health)
# Out:
# health_Posts :
#
# Id
# count     13214
# unique    13214
# top       14741
# freq          1
# Name: Id, dtype: object
#
#
# PostTypeId
# count     13214
# unique        6
# top           1
# freq       6930
# Name: PostTypeId, dtype: object
#
#
# AcceptedAnswerId
# count     13214
# unique     2203
# top          NA
# freq      11012
# Name: AcceptedAnswerId, dtype: object
#
#
# CreationDate
# count                       13214
# unique                      12978
# top       2018-06-11T16:49:10.997
# freq                            2
# Name: CreationDate, dtype: object
#
#
# Score
# count     13214
# unique       58
# top           1
# freq       3064
# Name: Score, dtype: object
#
#
# ViewCount
# count     13214
# unique     1321
# top          NA
# freq       6284
# Name: ViewCount, dtype: object
#
#
# Body
# count     13214
# unique    13052
# top
# freq        161
# Name: Body, dtype: object
#
#
# OwnerUserId
# count     13214
# unique     4419
# top        3002
# freq        436
# Name: OwnerUserId, dtype: object
#
#
# LastEditorUserId
# count     13214
# unique     1204
# top          NA
# freq       5779
# Name: LastEditorUserId, dtype: object
#
#
# LastEditDate
# count     13214
# unique     6837
# top          NA
# freq       5667
# Name: LastEditDate, dtype: object
#
#
# LastActivityDate
# count                       13214
# unique                      10511
# top       2020-04-26T17:44:41.663
# freq                            2
# Name: LastActivityDate, dtype: object
#
#
# Title
# count     13214
# unique     6930
# top          NA
# freq       6284
# Name: Title, dtype: object
#
#
# Tags
# count     13214
# unique     5555
# top          NA
# freq       6284
# Name: Tags, dtype: object
#
#
# AnswerCount
# count     13214
# unique        9
# top          NA
# freq       6284
# Name: AnswerCount, dtype: object
#
#
# CommentCount
# count     13214
# unique       21
# top           0
# freq       6034
# Name: CommentCount, dtype: object
#
#
# FavoriteCount
# count     13214
# unique       14
# top          NA
# freq      11386
# Name: FavoriteCount, dtype: object
#
#
# ContentLicense
# count            13214
# unique               2
# top       CC BY-SA 3.0
# freq              8301
# Name: ContentLicense, dtype: object
#
#
# ParentId
# count     13214
# unique     4535
# top          NA
# freq       7350
# Name: ParentId, dtype: object
#
#
# LastEditorDisplayName
# count     13214
# unique       35
# top          NA
# freq      13091
# Name: LastEditorDisplayName, dtype: object
#
#
# OwnerDisplayName
# count     13214
# unique      253
# top          NA
# freq      12812
# Name: OwnerDisplayName, dtype: object
#
#
# ClosedDate
# count     13214
# unique      814
# top          NA
# freq      12401
# Name: ClosedDate, dtype: object
#
#
# CommunityOwnedDate
# count     13214
# unique       28
# top          NA
# freq      13184
# Name: CommunityOwnedDate, dtype: object
#
#
# health_Comments :
#
# Id
# count     21707
# unique    21707
# top       25761
# freq          1
# Name: Id, dtype: object
#
#
# PostId
# count     21707
# unique     7180
# top       16000
# freq         21
# Name: PostId, dtype: object
#
#
# Score
# count     21707
# unique       17
# top           0
# freq      14476
# Name: Score, dtype: object
#
#
# Text
# count                                                 21707
# unique                                                21323
# top       Welcome to Medical Sciences! Please take the [...
# freq                                                     38
# Name: Text, dtype: object
#
#
# CreationDate
# count                       21707
# unique                      21707
# top       2017-12-13T16:27:22.297
# freq                            1
# Name: CreationDate, dtype: object
#
#
# UserId
# count     21707
# unique     2473
# top         805
# freq       2871
# Name: UserId, dtype: object
#
#
# ContentLicense
# count            21707
# unique               2
# top       CC BY-SA 3.0
# freq             11874
# Name: ContentLicense, dtype: object
#
#
# UserDisplayName
# count     21707
# unique      139
# top          NA
# freq      21311
# Name: UserDisplayName, dtype: object
#
#
# health_Badges :
#
# Id
# count     25527
# unique    25527
# top       16206
# freq          1
# Name: Id, dtype: object
#
#
# UserId
# count     25527
# unique     9737
# top        1830
# freq        108
# Name: UserId, dtype: object
#
#
# Name
# count              25527
# unique                76
# top       Autobiographer
# freq                5738
# Name: Name, dtype: object
#
#
# Date
# count                       25527
# unique                      22063
# top       2019-11-13T19:39:48.253
# freq                           66
# Name: Date, dtype: object
#
#
# Class
# count     25527
# unique        3
# top           3
# freq      23523
# Name: Class, dtype: object
#
#
# TagBased
# count     25527
# unique        2
# top       False
# freq      25520
# Name: TagBased, dtype: object
#
#
# health_PostLinks :
#
# Id
# count      1036
# unique     1036
# top       18787
# freq          1
# Name: Id, dtype: object
#
#
# CreationDate
# count                        1036
# unique                        992
# top       2020-08-04T13:52:17.970
# freq                            6
# Name: CreationDate, dtype: object
#
#
# PostId
# count      1036
# unique      803
# top       24340
# freq          7
# Name: PostId, dtype: object
#
#
# RelatedPostId
# count      1036
# unique      658
# top       11458
# freq         23
# Name: RelatedPostId, dtype: object
#
#
# LinkTypeId
# count     1036
# unique       2
# top          1
# freq       894
# Name: LinkTypeId, dtype: object
#
#
# health_PostHistory :
#
# Id
# count     49459
# unique    49459
# top       25761
# freq          1
# Name: Id, dtype: object
#
#
# PostHistoryTypeId
# count     49459
# unique       28
# top           2
# freq      13214
# Name: PostHistoryTypeId, dtype: object
#
#
# PostId
# count     49459
# unique    13214
# top       21182
# freq         40
# Name: PostId, dtype: object
#
#
# RevisionGUID
# count                                    49459
# unique                                   31738
# top       65148db1-3cc4-4471-a99a-38d76241accf
# freq                                         4
# Name: RevisionGUID, dtype: object
#
#
# CreationDate
# count                       49459
# unique                      30487
# top       2020-06-17T09:58:12.897
# freq                          568
# Name: CreationDate, dtype: object
#
#
# UserId
# count     49459
# unique     4483
# top          -1
# freq       3297
# Name: UserId, dtype: object
#
#
# Text
# count     49459
# unique    41327
# top          NA
# freq       3986
# Name: Text, dtype: object
#
#
# ContentLicense
# count            49459
# unique               3
# top       CC BY-SA 3.0
# freq             27999
# Name: ContentLicense, dtype: object
#
#
# Comment
# count     49459
# unique     7169
# top          NA
# freq      29081
# Name: Comment, dtype: object
#
#
# UserDisplayName
# count     49459
# unique      214
# top          NA
# freq      48169
# Name: UserDisplayName, dtype: object
#
#
# health_Tags :
#
# Id
# count     1439
# unique    1439
# top       3229
# freq         1
# Name: Id, dtype: object
#
#
# TagName
# count            1439
# unique           1439
# top       suffocation
# freq                1
# Name: TagName, dtype: object
#
#
# Count
# count     1439
# unique     101
# top          2
# freq       266
# Name: Count, dtype: object
#
#
# ExcerptPostId
# count     1439
# unique     187
# top         NA
# freq      1253
# Name: ExcerptPostId, dtype: object
#
#
# WikiPostId
# count     1439
# unique     187
# top         NA
# freq      1253
# Name: WikiPostId, dtype: object
#
#
# health_Users :
#
# Id
# count     15558
# unique    15558
# top       16206
# freq          1
# Name: Id, dtype: object
#
#
# Reputation
# count     15558
# unique      457
# top           1
# freq       6547
# Name: Reputation, dtype: object
#
#
# CreationDate
# count                       15558
# unique                      15558
# top       2017-12-13T16:27:22.297
# freq                            1
# Name: CreationDate, dtype: object
#
#
# DisplayName
# count     15558
# unique    14706
# top        John
# freq         27
# Name: DisplayName, dtype: object
#
#
# LastAccessDate
# count                       15558
# unique                      15558
# top       2017-12-13T16:27:22.297
# freq                            1
# Name: LastAccessDate, dtype: object
#
#
# Location
# count     15558
# unique     2489
# top          NA
# freq       9339
# Name: Location, dtype: object
#
#
# AboutMe
# count     15558
# unique     5504
# top          NA
# freq       9738
# Name: AboutMe, dtype: object
#
#
# Views
# count     15558
# unique      111
# top           0
# freq      10841
# Name: Views, dtype: object
#
#
# UpVotes
# count     15558
# unique      129
# top           0
# freq      12682
# Name: UpVotes, dtype: object
#
#
# DownVotes
# count     15558
# unique       60
# top           0
# freq      15275
# Name: DownVotes, dtype: object
#
#
# AccountId
# count        15558
# unique       15557
# top       16855164
# freq             2
# Name: AccountId, dtype: object
#
#
# ProfileImageUrl
# count     15558
# unique    13248
# top          NA
# freq       2232
# Name: ProfileImageUrl, dtype: object
#
#
# WebsiteUrl
# count     15558
# unique     2974
# top          NA
# freq      12192
# Name: WebsiteUrl, dtype: object
#
#
# health_Votes :
#
# Id
# count     70332
# unique    70332
# top       16206
# freq          1
# Name: Id, dtype: object
#
#
# PostId
# count     70332
# unique    18784
# top          52
# freq        144
# Name: PostId, dtype: object
#
#
# VoteTypeId
# count     70332
# unique       12
# top           2
# freq      43757
# Name: VoteTypeId, dtype: object
#
#
# CreationDate
# count                       70332
# unique                       2076
# top       2015-04-01T00:00:00.000
# freq                          399
# Name: CreationDate, dtype: object
#
#
# UserId
# count     70332
# unique      947
# top          NA
# freq      67308
# Name: UserId, dtype: object
#
#
# BountyAmount
# count     70332
# unique        9
# top          NA
# freq      70005
# Name: BountyAmount, dtype: object

# %% [markdown]
# \
# \
# Statistics of astronomy website:

# %%
stats(astronomy)
# Out:
# astro_Posts :
#
# Id
# count     24813
# unique    24813
# top       16206
# freq          1
# Name: Id, dtype: object
#
#
# PostTypeId
# count     24813
# unique        5
# top           2
# freq      14179
# Name: PostTypeId, dtype: object
#
#
# AcceptedAnswerId
# count     24813
# unique     5093
# top          NA
# freq      19721
# Name: AcceptedAnswerId, dtype: object
#
#
# CreationDate
# count                       24813
# unique                      24474
# top       2015-05-25T14:46:36.920
# freq                            2
# Name: CreationDate, dtype: object
#
#
# Score
# count     24813
# unique      106
# top           1
# freq       4299
# Name: Score, dtype: object
#
#
# ViewCount
# count     24813
# unique     2350
# top          NA
# freq      14818
# Name: ViewCount, dtype: object
#
#
# Body
# count     24813
# unique    24574
# top
# freq        235
# Name: Body, dtype: object
#
#
# OwnerUserId
# count     24813
# unique     6145
# top        2531
# freq       1226
# Name: OwnerUserId, dtype: object
#
#
# LastEditorUserId
# count     24813
# unique     1876
# top          NA
# freq      13416
# Name: LastEditorUserId, dtype: object
#
#
# LastEditDate
# count     24813
# unique    10778
# top          NA
# freq      13071
# Name: LastEditDate, dtype: object
#
#
# LastActivityDate
# count                       24813
# unique                      18362
# top       2017-03-24T17:14:23.697
# freq                            2
# Name: LastActivityDate, dtype: object
#
#
# Title
# count     24813
# unique     9992
# top          NA
# freq      14818
# Name: Title, dtype: object
#
#
# Tags
# count     24813
# unique     6430
# top          NA
# freq      14818
# Name: Tags, dtype: object
#
#
# AnswerCount
# count     24813
# unique       14
# top          NA
# freq      14818
# Name: AnswerCount, dtype: object
#
#
# CommentCount
# count     24813
# unique       28
# top           0
# freq       9824
# Name: CommentCount, dtype: object
#
#
# FavoriteCount
# count     24813
# unique       21
# top          NA
# freq      21973
# Name: FavoriteCount, dtype: object
#
#
# ContentLicense
# count            24813
# unique               2
# top       CC BY-SA 3.0
# freq             14400
# Name: ContentLicense, dtype: object
#
#
# OwnerDisplayName
# count     24813
# unique      278
# top          NA
# freq      24099
# Name: OwnerDisplayName, dtype: object
#
#
# ParentId
# count     24813
# unique     8767
# top          NA
# freq      10634
# Name: ParentId, dtype: object
#
#
# LastEditorDisplayName
# count     24813
# unique       50
# top          NA
# freq      24443
# Name: LastEditorDisplayName, dtype: object
#
#
# ClosedDate
# count     24813
# unique     1101
# top          NA
# freq      23713
# Name: ClosedDate, dtype: object
#
#
# CommunityOwnedDate
# count     24813
# unique       45
# top          NA
# freq      24769
# Name: CommunityOwnedDate, dtype: object
#
#
# astro_Comments :
#
# Id
# count     50952
# unique    50952
# top       16206
# freq          1
# Name: Id, dtype: object
#
#
# PostId
# count     50952
# unique    14989
# top       13531
# freq         28
# Name: PostId, dtype: object
#
#
# Score
# count     50952
# unique       39
# top           0
# freq      34248
# Name: Score, dtype: object
#
#
# Text
# count                                                 50952
# unique                                                50880
# top       Possible duplicate of [Star like light moving ...
# freq                                                      6
# Name: Text, dtype: object
#
#
# CreationDate
# count                       50952
# unique                      50938
# top       2015-10-22T11:48:33.200
# freq                            3
# Name: CreationDate, dtype: object
#
#
# UserId
# count     50952
# unique     4396
# top        7982
# freq       3933
# Name: UserId, dtype: object
#
#
# ContentLicense
# count            50952
# unique               2
# top       CC BY-SA 3.0
# freq             27631
# Name: ContentLicense, dtype: object
#
#
# UserDisplayName
# count     50952
# unique      185
# top          NA
# freq      49037
# Name: UserDisplayName, dtype: object
#
#
# astro_Badges :
#
# Id
# count     43085
# unique    43085
# top       16206
# freq          1
# Name: Id, dtype: object
#
#
# UserId
# count     43085
# unique    15275
# top        2531
# freq        493
# Name: UserId, dtype: object
#
#
# Name
# count              43085
# unique               115
# top       Autobiographer
# freq                9564
# Name: Name, dtype: object
#
#
# Date
# count                       43085
# unique                      36768
# top       2014-09-24T20:24:22.973
# freq                          509
# Name: Date, dtype: object
#
#
# Class
# count     43085
# unique        3
# top           3
# freq      37944
# Name: Class, dtype: object
#
#
# TagBased
# count     43085
# unique        2
# top       False
# freq      42973
# Name: TagBased, dtype: object
#
#
# astro_PostLinks :
#
# Id
# count       4287
# unique      4287
# top       339748
# freq           1
# Name: Id, dtype: object
#
#
# CreationDate
# count                        4287
# unique                       3898
# top       2020-07-25T05:55:54.063
# freq                            8
# Name: CreationDate, dtype: object
#
#
# PostId
# count      4287
# unique     2712
# top       36947
# freq         10
# Name: PostId, dtype: object
#
#
# RelatedPostId
# count      4287
# unique     2071
# top       11634
# freq        109
# Name: RelatedPostId, dtype: object
#
#
# LinkTypeId
# count     4287
# unique       2
# top          1
# freq      3587
# Name: LinkTypeId, dtype: object
#
#
# astro_PostHistory :
#
# Id
# count     78586
# unique    78586
# top       16206
# freq          1
# Name: Id, dtype: object
#
#
# PostHistoryTypeId
# count     78586
# unique       28
# top           2
# freq      24813
# Name: PostHistoryTypeId, dtype: object
#
#
# PostId
# count     78586
# unique    24813
# top       28484
# freq         34
# Name: PostId, dtype: object
#
#
# RevisionGUID
# count                                    78586
# unique                                   53543
# top       245cd734-1456-4f4e-b5f1-47507834452f
# freq                                         5
# Name: RevisionGUID, dtype: object
#
#
# CreationDate
# count                       78586
# unique                      51757
# top       2020-06-17T09:47:40.653
# freq                          465
# Name: CreationDate, dtype: object
#
#
# UserId
# count     78586
# unique     6300
# top          NA
# freq       9337
# Name: UserId, dtype: object
#
#
# Text
# count     78586
# unique    63418
# top          NA
# freq       9426
# Name: Text, dtype: object
#
#
# ContentLicense
# count            78586
# unique               3
# top       CC BY-SA 3.0
# freq             40571
# Name: ContentLicense, dtype: object
#
#
# UserDisplayName
# count     78586
# unique      218
# top          NA
# freq      76708
# Name: UserDisplayName, dtype: object
#
#
# Comment
# count     78586
# unique    15124
# top          NA
# freq      46637
# Name: Comment, dtype: object
#
#
# astro_Tags :
#
# Id
# count     487
# unique    487
# top       534
# freq        1
# Name: Id, dtype: object
#
#
# TagName
# count                        487
# unique                       487
# top       cosmological-principle
# freq                           1
# Name: TagName, dtype: object
#
#
# Count
# count     487
# unique    136
# top         1
# freq       29
# Name: Count, dtype: object
#
#
# ExcerptPostId
# count     487
# unique    295
# top        NA
# freq      193
# Name: ExcerptPostId, dtype: object
#
#
# WikiPostId
# count     487
# unique    295
# top        NA
# freq      193
# Name: WikiPostId, dtype: object
#
#
# astro_Users :
#
# Id
# count     26726
# unique    26726
# top       16206
# freq          1
# Name: Id, dtype: object
#
#
# Reputation
# count     26726
# unique      700
# top           1
# freq      13316
# Name: Reputation, dtype: object
#
#
# CreationDate
# count                       26726
# unique                      26726
# top       2015-01-03T15:09:43.803
# freq                            1
# Name: CreationDate, dtype: object
#
#
# DisplayName
# count     26726
# unique    25406
# top        John
# freq         31
# Name: DisplayName, dtype: object
#
#
# LastAccessDate
# count                       26726
# unique                      26726
# top       2018-02-16T08:07:12.760
# freq                            1
# Name: LastAccessDate, dtype: object
#
#
# WebsiteUrl
# count     26726
# unique     4941
# top          NA
# freq      20854
# Name: WebsiteUrl, dtype: object
#
#
# Location
# count     26726
# unique     3655
# top          NA
# freq      16445
# Name: Location, dtype: object
#
#
# AboutMe
# count     26726
# unique     9325
# top          NA
# freq      16913
# Name: AboutMe, dtype: object
#
#
# Views
# count     26726
# unique      162
# top           0
# freq      20552
# Name: Views, dtype: object
#
#
# UpVotes
# count     26726
# unique      234
# top           0
# freq      20669
# Name: UpVotes, dtype: object
#
#
# DownVotes
# count     26726
# unique       67
# top           0
# freq      26218
# Name: DownVotes, dtype: object
#
#
# AccountId
# count       26726
# unique      26726
# top       4564523
# freq            1
# Name: AccountId, dtype: object
#
#
# ProfileImageUrl
# count     26726
# unique    22779
# top          NA
# freq       3785
# Name: ProfileImageUrl, dtype: object
#
#
# astro_Votes :
#
# Id
# count     160512
# unique    160512
# top        16206
# freq           1
# Name: Id, dtype: object
#
#
# PostId
# count     160512
# unique     29074
# top        23164
# freq         163
# Name: PostId, dtype: object
#
#
# VoteTypeId
# count     160512
# unique        12
# top            2
# freq      116446
# Name: VoteTypeId, dtype: object
#
#
# CreationDate
# count                      160512
# unique                       2631
# top       2013-09-26T00:00:00.000
# freq                          430
# Name: CreationDate, dtype: object
#
#
# UserId
# count     160512
# unique      1578
# top           NA
# freq      155497
# Name: UserId, dtype: object
#
#
# BountyAmount
# count     160512
# unique        10
# top           NA
# freq      160109
# Name: BountyAmount, dtype: object

# %% [markdown]
#
#
#
#
# #### Now we look for repetitive data:
# Here we define function Repetitive which find the columns of a table of a website(given as argument to the function) wich has too many rows with sme values.I specify below to show variables with over 95% rows being the same value.

# %%
def Repetitive(data):
  for df in data:  
    name =[x for x in globals() if globals()[x] is df][0]
    print(name,':\n')
    num_rows = len(df.index)
    info = [] 

    for col in df.columns:
        
        cnt = df[col].value_counts(dropna=False)
        top_pct = (cnt/num_rows).iloc[0]
    
        if top_pct > 0.95:
            info.append(col)
            print('{0}: {1:.5f}%'.format(col, top_pct*100))
            print(cnt)
            print('\n\n')

# %% [markdown]
# \
# \
# #### Printing variables with over 95% repetitive rows:
# \
# For travel website:

# %%
Repetitive(travel)
# Out:
# travel_Posts :
#
# LastEditorDisplayName: 96.08311%
# NA           108768
# user67108      2424
# user89966       445
# user3470        419
# user141         239
#               ...
# user42025         1
# user26128         1
# user83262         1
# user58962         1
# user16830         1
# Name: LastEditorDisplayName, Length: 110, dtype: int64
#
#
#
# CommunityOwnedDate: 99.71025%
# NA                         112874
# 2011-08-03T04:53:46.420        12
# 2012-05-10T01:02:35.723        10
# 2012-11-07T01:22:44.580         6
# 2011-06-22T17:16:00.400         5
#                             ...
# 2011-11-10T11:32:50.013         1
# 2014-04-10T06:14:01.083         1
# 2012-06-26T21:10:21.537         1
# 2011-10-24T17:39:55.013         1
# 2017-11-24T11:50:01.810         1
# Name: CommunityOwnedDate, Length: 295, dtype: int64
#
#
#
# OwnerDisplayName: 96.44794%
# NA           109181
# user13044       926
# user141         614
# user89966       415
# user1712        251
#               ...
# user94903         1
# user65866         1
# user19940         1
# user73211         1
# user16830         1
# Name: OwnerDisplayName, Length: 436, dtype: int64
#
#
#
# travel_Comments :
#
# UserDisplayName: 97.04639%
# NA            247412
# user13044       1669
# user141          679
# user58558        518
# user1712         476
#                ...
# user6146           1
# user8535           1
# user29162          1
# user110724         1
# user6331           1
# Name: UserDisplayName, Length: 668, dtype: int64
#
#
#
# travel_Badges :
#
# TagBased: 99.47720%
# False    184569
# True        970
# Name: TagBased, dtype: int64
#
#
#
# travel_PostLinks :
#
# travel_PostHistory :
#
# UserDisplayName: 96.01399%
# NA           386897
# user67108      5972
# user141        1624
# user89966      1498
# user13044      1100
#               ...
# user90566         1
# user20429         1
# user74813         1
# Jamiec            1
# DeltaLima         1
# Name: UserDisplayName, Length: 402, dtype: int64
#
#
#
# travel_Tags :
#
# travel_Users :
#
# DownVotes: 97.67251%
# 0      83174
# 1        730
# 2        283
# 3        192
# 4         95
#        ...
# 233        1
# 278        1
# 61         1
# 535        1
# 40         1
# Name: DownVotes, Length: 167, dtype: int64
#
#
#
# travel_Votes :
#
# UserId: 97.85781%
# NA        904764
# 74643        850
# 101          732
# 11633        485
# 8494         400
#            ...
# 43270          1
# 68271          1
# 4699           1
# 10044          1
# 101039         1
# Name: UserId, Length: 4497, dtype: int64
#
#
#
# BountyAmount: 99.65011%
# NA     921335
# 50       2070
# 100       665
# 500       168
# 200       121
# 150        85
# 250        47
# 25         39
# 300        21
# 400         9
# 350         5
# 75          3
# 125         2
# Name: BountyAmount, dtype: int64

# %% [markdown]
# \
# For health website:

# %%
Repetitive(health)
# Out:
# health_Posts :
#
# LastEditorDisplayName: 99.06917%
# NA           13091
# user8225        36
# user1571        22
# user139         12
# user3462         9
# user283          9
# user3176         3
# user17735        2
# user10           2
# user147          2
# user1893         2
# user7610         1
# user8936         1
# user300          1
# user17176        1
# user2141         1
# user19471        1
# user11461        1
# user2603         1
# user12041        1
# user16570        1
# user17719        1
# user19153        1
# user11906        1
# user3750         1
# user958          1
# user6525         1
# user9868         1
# user9777         1
# anon             1
# user19159        1
# user14261        1
# user16463        1
# user3116         1
# user13924        1
# Name: LastEditorDisplayName, dtype: int64
#
#
#
# OwnerDisplayName: 96.95777%
# NA                12812
# user8225             35
# user1571             27
# user139              17
# user3462             13
#                   ...
# Friendly Ghost        1
# Felix Leung           1
# Ryko                  1
# Jeroen Ubbink         1
# user11263             1
# Name: OwnerDisplayName, Length: 253, dtype: int64
#
#
#
# CommunityOwnedDate: 99.77297%
# NA                         13184
# 2020-03-19T00:24:23.897        2
# 2020-03-27T18:40:04.870        2
# 2020-05-13T04:00:13.510        2
# 2017-10-24T05:31:40.547        1
# 2020-09-25T00:30:32.777        1
# 2018-10-23T00:22:59.877        1
# 2017-04-24T21:21:29.147        1
# 2017-11-01T23:36:02.363        1
# 2020-10-06T21:37:10.383        1
# 2018-07-02T17:00:51.950        1
# 2017-04-27T10:02:35.453        1
# 2020-05-23T05:46:49.150        1
# 2020-05-09T10:35:20.953        1
# 2015-04-30T03:48:37.353        1
# 2016-06-01T20:01:52.693        1
# 2017-11-03T22:58:59.173        1
# 2020-04-01T22:52:03.333        1
# 2020-09-14T04:14:53.717        1
# 2017-09-20T18:42:37.407        1
# 2020-03-20T22:50:11.287        1
# 2020-05-05T17:38:21.557        1
# 2018-10-25T18:50:45.587        1
# 2017-09-20T23:49:50.687        1
# 2020-05-11T04:00:52.753        1
# 2020-05-05T04:41:07.440        1
# 2015-12-05T14:10:13.100        1
# 2016-06-05T14:38:24.840        1
# Name: CommunityOwnedDate, dtype: int64
#
#
#
# health_Comments :
#
# UserDisplayName: 98.17570%
# NA             21311
# user8225          70
# user11906         17
# user6525          16
# user12041         14
#                ...
# user12481          1
# Jon Custer         1
# whatsisname        1
# user16226          1
# user2779           1
# Name: UserDisplayName, Length: 139, dtype: int64
#
#
#
# health_Badges :
#
# TagBased: 99.97258%
# False    25520
# True         7
# Name: TagBased, dtype: int64
#
#
#
# health_PostLinks :
#
# health_PostHistory :
#
# UserDisplayName: 97.39178%
# NA             48169
# user8225         293
# user1571          81
# user3462          68
# user139           35
#                ...
# user2516           1
# user12181          1
# kmm                1
# user15208          1
# user2501323        1
# Name: UserDisplayName, Length: 214, dtype: int64
#
#
#
# health_Tags :
#
# health_Users :
#
# DownVotes: 98.18100%
# 0       15275
# 1         105
# 2          49
# 3          19
# 4          17
# 5          10
# 8           5
# 7           5
# 9           4
# 18          4
# 6           4
# 13          3
# 20          3
# 11          3
# 12          3
# 40          2
# 29          2
# 22          2
# 26          2
# 381         1
# 473         1
# 248         1
# 14          1
# 21          1
# 87          1
# 56          1
# 24          1
# 17          1
# 33          1
# 172         1
# 126         1
# 23          1
# 47          1
# 697         1
# 41          1
# 583         1
# 241         1
# 27          1
# 38          1
# 104         1
# 96          1
# 42          1
# 3443        1
# 1417        1
# 215         1
# 454         1
# 61          1
# 112         1
# 82          1
# 193         1
# 243         1
# 46          1
# 456         1
# 232         1
# 19          1
# 252         1
# 72          1
# 133         1
# 48          1
# 10          1
# Name: DownVotes, dtype: int64
#
#
#
# health_Votes :
#
# UserId: 95.70039%
# NA       67308
# 11231      128
# 453        107
# 11958      106
# 74         105
#          ...
# 2070         1
# 9806         1
# 2350         1
# 491          1
# 12396        1
# Name: UserId, Length: 947, dtype: int64
#
#
#
# BountyAmount: 99.53506%
# NA     70005
# 50       222
# 100       79
# 150       10
# 25         8
# 250        3
# 300        2
# 400        2
# 200        1
# Name: BountyAmount, dtype: int64

# %% [markdown]
# \
# For astronomy website:

# %%
Repetitive(astronomy)
# Out:
# astro_Posts :
#
# OwnerDisplayName: 97.12248%
# NA              24099
# user21            127
# user8              87
# user2449           31
# user14781          17
#                 ...
# Quonux              1
# Coomie              1
# user23052           1
# Olin Lathrop        1
# user444             1
# Name: OwnerDisplayName, Length: 278, dtype: int64
#
#
#
# LastEditorDisplayName: 98.50885%
# NA           24443
# user1569       148
# user8           41
# user21          36
# user2449        24
# user15217       17
# user5434        12
# user10106        9
# user8021         8
# user34599        6
# user31179        6
# user14291        5
# user31880        4
# user5341         4
# user10250        3
# user13628        3
# user14781        3
# user2764         2
# user34615        2
# user28809        2
# user2233         2
# user15104        2
# user2216         2
# user20278        2
# user18491        2
# user8024         1
# user10219        1
# user24662        1
# user35491        1
# user2631         1
# user25868        1
# user14785        1
# user10           1
# user14607        1
# user17206        1
# user15430        1
# user19087        1
# user23319        1
# user34216        1
# user14116        1
# user24627        1
# user31132        1
# user35261        1
# user7330         1
# user23327        1
# user10636        1
# user27815        1
# user6996         1
# user14720        1
# user11722        1
# Name: LastEditorDisplayName, dtype: int64
#
#
#
# ClosedDate: 95.56684%
# NA                         23713
# 2017-12-26T23:08:01.413        1
# 2016-10-04T17:42:42.197        1
# 2015-11-23T19:15:55.587        1
# 2018-05-06T08:46:35.530        1
#                            ...
# 2018-06-25T13:15:00.303        1
# 2018-02-02T11:50:54.280        1
# 2018-06-03T00:28:09.050        1
# 2017-02-23T17:55:13.517        1
# 2020-04-12T23:04:16.487        1
# Name: ClosedDate, Length: 1101, dtype: int64
#
#
#
# CommunityOwnedDate: 99.82267%
# NA                         24769
# 2019-05-17T17:44:55.720        1
# 2018-10-11T18:28:53.780        1
# 2014-10-30T21:00:27.097        1
# 2019-11-29T16:45:51.700        1
# 2017-03-14T20:01:24.513        1
# 2020-07-29T18:20:20.350        1
# 2016-10-26T18:07:04.177        1
# 2016-11-23T12:49:00.260        1
# 2017-01-08T19:31:42.013        1
# 2016-08-30T13:58:21.943        1
# 2019-05-04T23:09:55.403        1
# 2015-01-17T23:04:42.283        1
# 2019-01-18T12:25:41.100        1
# 2017-06-05T18:28:35.440        1
# 2017-01-11T19:16:14.223        1
# 2018-07-09T03:39:34.710        1
# 2015-01-19T20:50:29.983        1
# 2016-10-26T18:08:53.133        1
# 2016-10-26T18:05:31.837        1
# 2018-11-26T18:44:11.590        1
# 2017-06-11T20:43:51.520        1
# 2017-03-10T22:46:59.337        1
# 2018-06-09T20:41:50.983        1
# 2017-04-29T10:11:52.970        1
# 2016-02-02T18:43:24.087        1
# 2019-05-13T20:11:25.403        1
# 2014-03-31T03:36:30.453        1
# 2020-07-20T14:03:43.297        1
# 2017-02-03T22:11:47.413        1
# 2017-01-15T20:28:07.930        1
# 2020-08-28T08:56:58.443        1
# 2020-09-21T19:34:59.837        1
# 2017-06-11T19:49:20.110        1
# 2017-01-07T23:23:10.463        1
# 2018-10-12T01:12:13.517        1
# 2018-12-30T21:05:08.220        1
# 2016-12-30T09:04:19.093        1
# 2017-01-12T20:32:45.373        1
# 2015-06-10T17:12:07.410        1
# 2017-01-03T09:48:50.460        1
# 2014-02-25T19:34:04.580        1
# 2014-03-28T20:18:48.500        1
# 2017-01-15T20:47:37.353        1
# 2017-09-25T17:57:16.783        1
# Name: CommunityOwnedDate, dtype: int64
#
#
#
# astro_Comments :
#
# UserDisplayName: 96.24156%
# NA                49037
# user21             1065
# user1569            187
# user10106            70
# user34599            50
#                   ...
# user13721             1
# user10713             1
# WhatRoughBeast        1
# ZeroTheHero           1
# CR Drost              1
# Name: UserDisplayName, Length: 185, dtype: int64
#
#
#
# astro_Badges :
#
# TagBased: 99.74005%
# False    42973
# True       112
# Name: TagBased, dtype: int64
#
#
#
# astro_PostLinks :
#
# astro_PostHistory :
#
# UserDisplayName: 97.61026%
# NA           76708
# user1569       289
# user21         235
# user8          220
# user2449        89
#              ...
# user23728        1
# Uwe              1
# user30930        1
# PtAltaria        1
# user17206        1
# Name: UserDisplayName, Length: 218, dtype: int64
#
#
#
# astro_Tags :
#
# astro_Users :
#
# DownVotes: 98.09923%
# 0      26218
# 1        191
# 2         82
# 3         39
# 4         25
#        ...
# 90         1
# 278        1
# 51         1
# 715        1
# 467        1
# Name: DownVotes, Length: 67, dtype: int64
#
#
#
# astro_Votes :
#
# UserId: 96.87562%
# NA       155497
# 2153        488
# 7982        234
# 22074       144
# 10589        93
#           ...
# 27970         1
# 21759         1
# 1626          1
# 2773          1
# 29259         1
# Name: UserId, Length: 1578, dtype: int64
#
#
#
# BountyAmount: 99.74893%
# NA     160109
# 50        196
# 100       171
# 200        15
# 25          7
# 150         4
# 300         4
# 250         3
# 500         2
# 75          1
# Name: BountyAmount, dtype: int64
